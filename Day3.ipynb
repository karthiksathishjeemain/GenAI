# %% [markdown]
# <a href="https://colab.research.google.com/github/karthiksathishjeemain/GenAI/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("train (1).csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.iloc[:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(ax=ax[0])
ax[0].set_ylabel("")
ax[0].set_title("Sur")
# sns.countplot(data=data,x='Survived',ax=ax[0])

sns.countplot(data=data,x='Survived',ax=ax[1])
plt.show()
ax[1].set_title("Sujhbh")
plt.show()

# %%
(data.groupby(["Survived","Sex"])).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Survived Sex
# 0        female           81      81    81   64     81     81      81    81
#          male            468     468   468  360    468    468     468   468
# 1        female          233     233   233  197    233    233     233   233
#          male            109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Survived Sex
# 0        female      6        81
#          male       62       468
# 1        female     91       231
#          male       45       109

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.countplot(x=data["Sex"],ax=ax[0])
sns.countplot(x=data["Sex"],ax=ax[1],hue=data["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data.groupby(["Sex","Pclass","Survived"])["Pclass"].count().plot.bar(ax=ax[0])
# Out:
# <Axes: xlabel='Sex,Pclass,Survived'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data["Pclass"].value_counts().plot.bar(ax=ax[0])
sns.countplot(x="Pclass",data=data,hue="Survived",ax=ax[1])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pd.crosstab(data["Survived"],data["Pclass"],margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
pd.crosstab([data.Sex,data.Survived],data["Pclass"],margins= True).style.background_gradient(cmap="summer_r")
# Out:
# <style type="text/css">
# #T_fc8ee_row0_col0, #T_fc8ee_row0_col1, #T_fc8ee_row0_col3, #T_fc8ee_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fc8ee_row0_col2, #T_fc8ee_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_fc8ee_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_fc8ee_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_fc8ee_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_fc8ee_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_fc8ee_row2_col1, #T_fc8ee_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_fc8ee_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_fc8ee_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_fc8ee_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_fc8ee_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# ...

# %%
sns.catplot(y='Survived',x='Pclass' ,hue='Sex', data=data, kind='point')

# %%
print ("Oldest age is ",data["Age"].max(),"years")
# Out:
# Oldest age is  80.0 years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot(x="Pclass",y="Age",hue="Survived",data=data,ax=ax[0])
sns.violinplot(x="Sex",y="Age",hue="Survived",data=data,ax=ax[1])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
data["Age"].isnull().sum()
# Out:
# 177

# %%
data["Initial"]=0
for i in data:
   data["Initial"]=data.Name.str.extract('([A-Za-z]+)\.')

# %%
data["Initial"].count()
# Out:
# 891

# %%
pd.crosstab(data.Sex,data.Initial,)
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
data["Initial"].replace(["Mlle","Mme","Ms","Countess","Lady","Capt","Col","Don","Dr","Jonkheer","Major","Rev","Sir"],["Miss","Miss","Miss","Mrs","Mrs","Mr","Mr","Mr","Mr","Mr","Mr","Mr","Mr"],inplace=True)

# %%
pd.crosstab(data.Sex,data.Initial)
# Out:
# Initial  Master  Miss   Mr  Mrs
# Sex
# female        0   186    1  127
# male         40     0  537    0

# %%
data.groupby("Initial")["Age"].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        33.022727
# Mrs       35.981818
# Name: Age, dtype: float64

# %%
data.Initial.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Initial, Length: 891, dtype: bool

# %%
# data.loc[(data.Age.isnull())&(data.Initial=="Mr"),"Age"]=33
# data.loc[(data.Age.isnull())&(data.Initial=="Mrs"),"Age"]=35
# data.loc[(data.Age.isnull())&(data.Initial=="Master"),"Age"]=5
# data.loc[(data.Age.isnull())&(data.Initial=="Miss"),"Age"]=22
## Assigning the NaN Values with the Ceil values of the mean ages
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
pd.crosstab(data.Age,data.Initial)
# Out:
# Initial  Master  Miss  Mr  Mrs
# Age
# 0.42          1     0   0    0
# 0.67          1     0   0    0
# 0.75          0     2   0    0
# 0.83          2     0   0    0
# 0.92          1     0   0    0
# ...         ...   ...  ..  ...
# 70.00         0     0   2    0
# 70.50         0     0   1    0
# 71.00         0     0   2    0
# 74.00         0     0   1    0
# 80.00         0     0   1    0
#
# [88 rows x 4 columns]

# %%
data.groupby(["Age","Initial"]).count()
# Out:
#                PassengerId  Survived  Pclass  Name  Sex  SibSp  Parch  Ticket  \
# Age   Initial
# 0.42  Master             1         1       1     1    1      1      1       1
# 0.67  Master             1         1       1     1    1      1      1       1
# 0.75  Miss               2         2       2     2    2      2      2       2
# 0.83  Master             2         2       2     2    2      2      2       2
# 0.92  Master             1         1       1     1    1      1      1       1
# ...                    ...       ...     ...   ...  ...    ...    ...     ...
# 70.00 Mr                 2         2       2     2    2      2      2       2
# 70.50 Mr                 1         1       1     1    1      1      1       1
# 71.00 Mr                 2         2       2     2    2      2      2       2
# 74.00 Mr                 1         1       1     1    1      1      1       1
# 80.00 Mr                 1         1       1     1    1      1      1       1
#
# ...

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data.Survived==0]["Age"].plot.hist(ax=ax[0],color="yellow",bins=20,edgecolor="black")
data[data.Survived==1].Age.plot.hist(ax=ax[1],color="red",bins=20,edgecolor="black")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Age"].plot.hist(x="Age",color="blue",edgecolor="black",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data[data.Initial=="Mr"]["Age"].count()
# Out:
# 538

# %%
(data["Initial"].value_counts())
# Out:
# Mr        538
# Miss      186
# Mrs       127
# Master     40
# Name: Initial, dtype: int64

# %%
data.Initial.value_counts().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(data=data,x="Initial")
# Out:
# <Axes: xlabel='Initial', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))
data["Age"].value_counts().plot.hist(ax=ax[0],edgecolor="black",bins=20)
data["Age"].plot.hist(ax=ax[1],edgecolor="black",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
pd.crosstab([data.Initial,data.Survived],data.Pclass)
# Out:
# Pclass             1   2    3
# Initial Survived
# Master  0          0   0   17
#         1          3   9   11
# Miss    0          2   2   51
#         1         47  33   51
# Mr      0         77  91  283
#         1         43   8   36
# Mrs     0          1   4   21
#         1         43  37   21

# %%
sns.catplot(x="Pclass", y="Survived", hue="Sex",data=data, kind="point")

# %%
data["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.catplot(x="Pclass",y="Survived",col="Initial",data=data,kind="point")

# %%
sns.catplot(data=data,x="Embarked",y="Survived",kind="point")

# %%
data.Survived.mean()
# Out:
# 0.3838383838383838

# %%
sns.catplot(data=data,x="Pclass",y="Survived",kind="point")

# %%
sns.catplot(data=data,x="Pclass",y="Survived",kind="point",hue="Sex")

# %%
sns.barplot(data=data,x="SibSp",y="Survived")
# Out:
# <Axes: xlabel='SibSp', ylabel='Survived'>

# %%
data.Embarked.fillna("S",inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %%
data.AgeBand=0

# %%
data.loc[data.Age<=16,"AgeBand"]=0
data.loc[(data.Age>16) & (data.Age<=32),"AgeBand"]=1
data.loc[(data.Age>32)&(data.Age<=48),"AgeBand"]=2
data.loc[(data.Age>48)&(data.Age<=64),"AgeBand"]=3
data.loc[(data.Age>64)&(data.Age<=80),"AgeBand"]=4

# %%
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  AgeBand
# 0      0  A/5 21171   7.2500   NaN        S      Mr      1.0
# 1      0   PC 17599  71.2833   C85        C     Mrs      2.0

# %%
data["AgeBand"].value_counts().to_frame().style.background_gradient (cmap="summer")
# Out:
# <style type="text/css">
# #T_5750a_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_5750a_row1_col0 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_5750a_row2_col0 {
#   background-color: #40a066;
#   color: #f1f1f1;
# }
# #T_5750a_row3_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_5750a_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5750a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5750a_level0_col0" class="col_heading level0 col0" >AgeBand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5750a_level0_row0" class="row_heading level0 row0" >1.000000</th>
#       <td id="T_5750a_row0_col0" class="data row0 col0" >382</td>
#     </tr>
#     <tr>
#       <th id="T_5750a_level0_row1" class="row_heading level0 row1" >2.000000</th>
#       <td id="T_5750a_row1_col0" class="data row1 col0" >325</td>
# ...

# %%
sns.catplot(data=data,x="AgeBand",col="Pclass",y="Survived",kind="point")

# %%
data["Single"]=0;
data["Family_Size"]=0;
data["Family_Size"]=data["Parch"]+data["SibSp"]
data.loc[data.Family_Size==0,"Single"]=1

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))
sns.pointplot(data=data,x="Family_Size",y="Survived",ax=ax[0],)
sns.pointplot(data=data,x="Single",y="Survived",ax=ax[1])
# Out:
# <Axes: xlabel='Single', ylabel='Survived'>

# %%
data["FareRange"]=pd.qcut(data["Fare"],4)
data.groupby(data.FareRange).Survived.count()
# Out:
# Fare
# (-0.001, 7.91]     223
# (7.91, 14.454]     224
# (14.454, 31.0]     222
# (31.0, 512.329]    222
# Name: Survived, dtype: int64

# %%
pd.crosstab(data.FareRange,data.Pclass,margins=True)
# Out:
# Pclass             1    2    3  All
# Fare
# (-0.001, 7.91]     6    6  211  223
# (7.91, 14.454]     0   86  138  224
# (14.454, 31.0]    51   70  101  222
# (31.0, 512.329]  159   22   41  222
# All              216  184  491  891

# %%
data.Fare_cat=0

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.pointplot(data=data,x="Fare_cat",y="Survived",hue="Sex")
# Out:
# <Axes: xlabel='Fare_cat', ylabel='Survived'>

# %%
data.Sex.replace(["male","female"],[0,1],inplace=True)
data.Embarked.replace(["S","Q","C"],[0,2,1],inplace=True)
data.Initial.replace(["Mr","Mrs","Miss","Master"],[0,1,2,3],inplace=True)

# %%
data.Embarked.value_counts()
# Out:
# 0    646
# 1    168
# 2     77
# Name: Embarked, dtype: int64

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','FareRange','PassengerId'],axis=1,inplace=True)

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
